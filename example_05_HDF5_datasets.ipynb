# %% [markdown]
# # Summary
# This tutorial demonstrates how to use HDF5 files with pylearn2. By using the Pylearn2 HDF5Dataset class, we avoid loading the entire dataset into memory.

# %%
import sys
import os
import pickle
import numpy
import theano
import pylearn2
import pylearn2.datasets
import pylearn2.training_algorithms
import pylearn2.training_algorithms.sgd
import pylearn2.costs
import pylearn2.models.mlp as mlp
import pylearn2.train
import pylearn2.termination_criteria
import pylearn2.datasets.hdf5
import matplotlib
import matplotlib.pyplot as plt
import h5py
# %matplotlib inline
# Out:
# Using gpu device 0: Tesla C2070 (CNMeM is disabled)

# %% [markdown]
# # Data set
# Below, we first write our data set into HDF5 format, then instantiate two HDF5Dataset objects for training the model.

# %%
# Load sample of MNIST data.
filename = './MNIST_2000.csv'
X = numpy.loadtxt(filename, dtype='float32')
X, labels = X[:,1:], X[:,0].astype('uint8') # First column is label (0-9)
y = numpy.zeros((X.shape[0], 10), dtype='float32')
for i,label in enumerate(labels):
    y[i, label] = 1.0

# Split data into train, test.
X_train, y_train = X[:1000, :], y[:1000, :]
X_test, y_test = X[1000:, :], y[1000:, :]

# Write data sets to HDF5 files.

def write_h5file(h5filename, X, y):
    # Save data to HDF5
    with h5py.File(h5filename, 'w') as f:
        f.create_dataset('X', data=X)
        f.create_dataset('y', data=y)

write_h5file('./MNIST_train.h5', X_train, y_train)
write_h5file('./MNIST_test.h5', X_test, y_test)

dataset_train = pylearn2.datasets.hdf5.HDF5Dataset(filename='./MNIST_train.h5', X='X', y='y')
dataset_test = pylearn2.datasets.hdf5.HDF5Dataset(filename='./MNIST_test.h5', X='X', y='y')

# %% [markdown]
# # Model
# Model training proceeds as usual.

# %%
layers = []
nvis = dataset_train.X.shape[1] # Number of input features.
nhid = 100 # Hidden neurons per layer.

# Layer 0
istdev = 1.0/numpy.sqrt(nvis)         # Initial weights selected from normal distribution.
layer = pylearn2.models.mlp.RectifiedLinear(layer_name = 'h0', dim=nhid, istdev=istdev)
layers.append(layer)

# Layer 1
istdev = 1.0/numpy.sqrt(nhid)
layer = pylearn2.models.mlp.RectifiedLinear(layer_name = 'h1', dim=nhid, istdev=istdev)
layers.append(layer)

# Output layer.
layer = mlp.Softmax(layer_name='y', n_classes=10, istdev=0.001)
layers.append(layer)

# MLP Model
model = pylearn2.models.mlp.MLP(layers, nvis=nvis, seed=36)

# %% [markdown]
# # Training Algorithm

# %%
# Cost/objective function.
cost = pylearn2.costs.mlp.Default()      # Defaults to cross-entropy loss for softmax output.
    
# Algorithm
args = {}
args['cost'] = cost
args['learning_rate'] = 0.1
args['batch_size']    = 100
args['learning_rule'] = pylearn2.training_algorithms.learning_rule.Momentum(init_momentum = 0.5)
args['monitoring_dataset'] = {'train':dataset_train, 'test':dataset_test}
args['termination_criterion'] = pylearn2.termination_criteria.EpochCounter(max_epochs=20)
algorithm = pylearn2.training_algorithms.sgd.SGD(**args)

# Train object.
filename_model = './model_mnist.pkl'
train = pylearn2.train.Train(dataset=dataset_train,
                             model=model,
                             algorithm=algorithm,
                             #extensions=extensions,
                             save_path=filename_model,
                             save_freq=5)

# %% [markdown]
# # Train model

# %%
# Run training loop.
train.main_loop()
# Out:
# Parameter and initial learning rate summary:
# 	h0_W: 0.10000000149
# 	h0_b: 0.10000000149
# 	h1_W: 0.10000000149
# 	h1_b: 0.10000000149
# 	softmax_b: 0.10000000149
# 	softmax_W: 0.10000000149
# Compiling sgd_update...
# Compiling sgd_update done. Time elapsed: 1.140645 seconds
# compiling begin_record_entry...
# compiling begin_record_entry done. Time elapsed: 0.429069 seconds
# Monitored channels:
# 	learning_rate
# 	momentum
# 	test_h0_col_norms_max
# 	test_h0_col_norms_mean
# 	test_h0_col_norms_min
# 	test_h0_max_x_max_u
# 	test_h0_max_x_mean_u
# 	test_h0_max_x_min_u
# 	test_h0_mean_x_max_u
# 	test_h0_mean_x_mean_u
# 	test_h0_mean_x_min_u
# 	test_h0_min_x_max_u
# 	test_h0_min_x_mean_u
# 	test_h0_min_x_min_u
# 	test_h0_range_x_max_u
# 	test_h0_range_x_mean_u
# 	test_h0_range_x_min_u
# 	test_h0_row_norms_max
# 	test_h0_row_norms_mean
# 	test_h0_row_norms_min
# 	test_h1_col_norms_max
# 	test_h1_col_norms_mean
# 	test_h1_col_norms_min
# 	test_h1_max_x_max_u
# 	test_h1_max_x_mean_u
# 	test_h1_max_x_min_u
# 	test_h1_mean_x_max_u
# 	test_h1_mean_x_mean_u
# 	test_h1_mean_x_min_u
# 	test_h1_min_x_max_u
# 	test_h1_min_x_mean_u
# 	test_h1_min_x_min_u
# 	test_h1_range_x_max_u
# 	test_h1_range_x_mean_u
# 	test_h1_range_x_min_u
# 	test_h1_row_norms_max
# 	test_h1_row_norms_mean
# 	test_h1_row_norms_min
# 	test_objective
# 	test_y_col_norms_max
# 	test_y_col_norms_mean
# 	test_y_col_norms_min
# 	test_y_max_max_class
# 	test_y_mean_max_class
# 	test_y_min_max_class
# 	test_y_misclass
# 	test_y_nll
# 	test_y_row_norms_max
# 	test_y_row_norms_mean
# 	test_y_row_norms_min
# 	total_seconds_last_epoch
# 	train_h0_col_norms_max
# 	train_h0_col_norms_mean
# 	train_h0_col_norms_min
# 	train_h0_max_x_max_u
# 	train_h0_max_x_mean_u
# 	train_h0_max_x_min_u
# 	train_h0_mean_x_max_u
# 	train_h0_mean_x_mean_u
# 	train_h0_mean_x_min_u
# 	train_h0_min_x_max_u
# 	train_h0_min_x_mean_u
# 	train_h0_min_x_min_u
# 	train_h0_range_x_max_u
# 	train_h0_range_x_mean_u
# 	train_h0_range_x_min_u
# 	train_h0_row_norms_max
# 	train_h0_row_norms_mean
# 	train_h0_row_norms_min
# 	train_h1_col_norms_max
# 	train_h1_col_norms_mean
# 	train_h1_col_norms_min
# 	train_h1_max_x_max_u
# 	train_h1_max_x_mean_u
# 	train_h1_max_x_min_u
# 	train_h1_mean_x_max_u
# 	train_h1_mean_x_mean_u
# 	train_h1_mean_x_min_u
# 	train_h1_min_x_max_u
# 	train_h1_min_x_mean_u
# 	train_h1_min_x_min_u
# 	train_h1_range_x_max_u
# 	train_h1_range_x_mean_u
# 	train_h1_range_x_min_u
# 	train_h1_row_norms_max
# 	train_h1_row_norms_mean
# 	train_h1_row_norms_min
# 	train_objective
# 	train_y_col_norms_max
# 	train_y_col_norms_mean
# 	train_y_col_norms_min
# 	train_y_max_max_class
# 	train_y_mean_max_class
# 	train_y_min_max_class
# 	train_y_misclass
# 	train_y_nll
# 	train_y_row_norms_max
# 	train_y_row_norms_mean
# 	train_y_row_norms_min
# 	training_seconds_this_epoch
# Compiling accum...
# graph size: 331
# graph size: 315
# Compiling accum done. Time elapsed: 10.521963 seconds
# Monitoring step:
# 	Epochs seen: 0
# 	Batches seen: 0
# 	Examples seen: 0
# 	learning_rate: 0.099999986589
# 	momentum: 0.500000059605
# 	test_h0_col_norms_max: 1.06272411346
# 	test_h0_col_norms_mean: 1.00180494785
# 	test_h0_col_norms_min: 0.94033241272
# 	test_h0_max_x_max_u: 1.44173371792
# 	test_h0_max_x_mean_u: 0.644945144653
# 	test_h0_max_x_min_u: 0.0393124967813
# 	test_h0_mean_x_max_u: 0.649418830872
# 	test_h0_mean_x_mean_u: 0.133668914437
# 	test_h0_mean_x_min_u: 0.000591475865804
# 	test_h0_min_x_max_u: 0.0275801625103
# 	test_h0_min_x_mean_u: 0.000275801605312
# 	test_h0_min_x_min_u: 0.0
# 	test_h0_range_x_max_u: 1.41902625561
# 	test_h0_range_x_mean_u: 0.644669353962
# 	test_h0_range_x_min_u: 0.0393124967813
# 	test_h0_row_norms_max: 0.43685349822
# 	test_h0_row_norms_mean: 0.356941491365
# 	test_h0_row_norms_min: 0.280473798513
# 	test_h1_col_norms_max: 1.20874929428
# 	test_h1_col_norms_mean: 1.00676298141
# 	test_h1_col_norms_min: 0.806728541851
# 	test_h1_max_x_max_u: 1.00942623615
# 	test_h1_max_x_mean_u: 0.406806230545
# 	test_h1_max_x_min_u: 0.0
# 	test_h1_mean_x_max_u: 0.395200431347
# 	test_h1_mean_x_mean_u: 0.0980800911784
# 	test_h1_mean_x_min_u: 0.0
# 	test_h1_min_x_max_u: 0.0461700670421
# 	test_h1_min_x_mean_u: 0.000567106995732
# 	test_h1_min_x_min_u: 0.0
# 	test_h1_range_x_max_u: 0.996873319149
# 	test_h1_range_x_mean_u: 0.406239151955
# 	test_h1_range_x_min_u: 0.0
# 	test_h1_row_norms_max: 1.16290199757
# 	test_h1_row_norms_mean: 1.0068975687
# 	test_h1_row_norms_min: 0.864736914635
# 	test_objective: 2.30256080627
# 	test_y_col_norms_max: 0.0103744743392
# 	test_y_col_norms_mean: 0.009660246782
# 	test_y_col_norms_min: 0.00870714895427
# 	test_y_max_max_class: 0.100585304201
# 	test_y_mean_max_class: 0.100267209113
# 	test_y_min_max_class: 0.100082024932
# 	test_y_misclass: 0.879999995232
# 	test_y_nll: 2.30256080627
# 	test_y_row_norms_max: 0.00512082641944
# 	test_y_row_norms_mean: 0.00298687024042
# 	test_y_row_norms_min: 0.0010757187847
# 	total_seconds_last_epoch: 0.0
# 	train_h0_col_norms_max: 1.06272411346
# 	train_h0_col_norms_mean: 1.00180494785
# 	train_h0_col_norms_min: 0.94033241272
# 	train_h0_max_x_max_u: 1.38562130928
# 	train_h0_max_x_mean_u: 0.635100126266
# 	train_h0_max_x_min_u: 0.0533090718091
# 	train_h0_mean_x_max_u: 0.628859221935
# 	train_h0_mean_x_mean_u: 0.131119459867
# 	train_h0_mean_x_min_u: 0.00080011296086
# 	train_h0_min_x_max_u: 0.0397322028875
# 	train_h0_min_x_mean_u: 0.000397322059143
# 	train_h0_min_x_min_u: 0.0
# 	train_h0_range_x_max_u: 1.38011538982
# 	train_h0_range_x_mean_u: 0.634702801704
# 	train_h0_range_x_min_u: 0.0533090718091
# 	train_h0_row_norms_max: 0.43685349822
# 	train_h0_row_norms_mean: 0.356941491365
# 	train_h0_row_norms_min: 0.280473798513
# 	train_h1_col_norms_max: 1.20874929428
# 	train_h1_col_norms_mean: 1.00676298141
# 	train_h1_col_norms_min: 0.806728541851
# 	train_h1_max_x_max_u: 0.959411621094
# 	train_h1_max_x_mean_u: 0.399134337902
# 	train_h1_max_x_min_u: 0.0
# 	train_h1_mean_x_max_u: 0.402670681477
# 	train_h1_mean_x_mean_u: 0.0960004329681
# 	train_h1_mean_x_min_u: 0.0
# 	train_h1_min_x_max_u: 0.0696794986725
# 	train_h1_min_x_mean_u: 0.000998697709292
# 	train_h1_min_x_min_u: 0.0
# 	train_h1_range_x_max_u: 0.939600527287
# 	train_h1_range_x_mean_u: 0.398135662079
# 	train_h1_range_x_min_u: 0.0
# 	train_h1_row_norms_max: 1.16290199757
# 	train_h1_row_norms_mean: 1.0068975687
# 	train_h1_row_norms_min: 0.864736914635
# 	train_objective: 2.30260586739
# 	train_y_col_norms_max: 0.0103744743392
# 	train_y_col_norms_mean: 0.009660246782
# 	train_y_col_norms_min: 0.00870714895427
# 	train_y_max_max_class: 0.100583769381
# 	train_y_mean_max_class: 0.100261345506
# 	train_y_min_max_class: 0.100080445409
# 	train_y_misclass: 0.89099997282
# 	train_y_nll: 2.30260586739
# 	train_y_row_norms_max: 0.00512082641944
# 	train_y_row_norms_mean: 0.00298687024042
# 	train_y_row_norms_min: 0.0010757187847
# 	training_seconds_this_epoch: 0.0
# Time this epoch: 0.076504 seconds
# Monitoring step:
# 	Epochs seen: 1
# 	Batches seen: 10
# 	Examples seen: 1000
# 	learning_rate: 0.099999986589
# 	momentum: 0.500000059605
# 	test_h0_col_norms_max: 1.0627515316
# 	test_h0_col_norms_mean: 1.00198495388
# 	test_h0_col_norms_min: 0.940323114395
# 	test_h0_max_x_max_u: 1.4717758894
# 	test_h0_max_x_mean_u: 0.66315984726
# 	test_h0_max_x_min_u: 0.0384505018592
# 	test_h0_mean_x_max_u: 0.657794594765
# 	test_h0_mean_x_mean_u: 0.140545859933
# 	test_h0_mean_x_min_u: 0.000591710035224
# 	test_h0_min_x_max_u: 0.0340499989688
# 	test_h0_min_x_mean_u: 0.000340500002494
# 	test_h0_min_x_min_u: 0.0
# 	test_h0_range_x_max_u: 1.45297896862
# 	test_h0_range_x_mean_u: 0.662819385529
# 	test_h0_range_x_min_u: 0.0384505018592
# 	test_h0_row_norms_max: 0.43685528636
# 	test_h0_row_norms_mean: 0.35700532794
# 	test_h0_row_norms_min: 0.280473798513
# 	test_h1_col_norms_max: 1.20875167847
# 	test_h1_col_norms_mean: 1.00693702698
# 	test_h1_col_norms_min: 0.807069003582
# 	test_h1_max_x_max_u: 1.0623421669
# 	test_h1_max_x_mean_u: 0.428363919258
# 	test_h1_max_x_min_u: 0.0
# 	test_h1_mean_x_max_u: 0.397820621729
# 	test_h1_mean_x_mean_u: 0.104200258851
# 	test_h1_mean_x_min_u: 0.0
# 	test_h1_min_x_max_u: 0.0317041091621
# 	test_h1_min_x_mean_u: 0.000390867382521
# 	test_h1_min_x_min_u: 0.0
# 	test_h1_range_x_max_u: 1.0562684536
# 	test_h1_range_x_mean_u: 0.427973091602
# 	test_h1_range_x_min_u: 0.0
# 	test_h1_row_norms_max: 1.16293859482
# 	test_h1_row_norms_mean: 1.00707542896
# 	test_h1_row_norms_min: 0.864998340607
# 	test_objective: 2.2671046257
# 	test_y_col_norms_max: 0.11124061048
# 	test_y_col_norms_mean: 0.0754992589355
# 	test_y_col_norms_min: 0.053731944412
# 	test_y_max_max_class: 0.115364506841
# 	test_y_mean_max_class: 0.106587290764
# 	test_y_min_max_class: 0.102818973362
# 	test_y_misclass: 0.584999978542
# 	test_y_nll: 2.2671046257
# 	test_y_row_norms_max: 0.0558791719377
# 	test_y_row_norms_mean: 0.0203072223812
# 	test_y_row_norms_min: 0.00219676503912
# 	total_seconds_last_epoch: 0.0
# 	train_h0_col_norms_max: 1.0627515316
# 	train_h0_col_norms_mean: 1.00198495388
# 	train_h0_col_norms_min: 0.940323114395
# 	train_h0_max_x_max_u: 1.42723119259
# 	train_h0_max_x_mean_u: 0.652235984802
# 	train_h0_max_x_min_u: 0.0534820333123
# 	train_h0_mean_x_max_u: 0.638325154781
# 	train_h0_mean_x_mean_u: 0.137875661254
# 	train_h0_mean_x_min_u: 0.000787791388575
# 	train_h0_min_x_max_u: 0.0474192835391
# 	train_h0_min_x_mean_u: 0.000474192842375
# 	train_h0_min_x_min_u: 0.0
# 	train_h0_range_x_max_u: 1.42723119259
# 	train_h0_range_x_mean_u: 0.651761770248
# 	train_h0_range_x_min_u: 0.0534820333123
# 	train_h0_row_norms_max: 0.43685528636
# 	train_h0_row_norms_mean: 0.35700532794
# 	train_h0_row_norms_min: 0.280473798513
# 	train_h1_col_norms_max: 1.20875167847
# 	train_h1_col_norms_mean: 1.00693702698
# 	train_h1_col_norms_min: 0.807069003582
# 	train_h1_max_x_max_u: 1.02196538448
# 	train_h1_max_x_mean_u: 0.419982761145
# 	train_h1_max_x_min_u: 0.0
# 	train_h1_mean_x_max_u: 0.406646072865
# 	train_h1_mean_x_mean_u: 0.102122284472
# 	train_h1_mean_x_min_u: 0.0
# 	train_h1_min_x_max_u: 0.0540733486414
# 	train_h1_min_x_mean_u: 0.000737457594369
# 	train_h1_min_x_min_u: 0.0
# 	train_h1_range_x_max_u: 1.01091790199
# 	train_h1_range_x_mean_u: 0.419245332479
# 	train_h1_range_x_min_u: 0.0
# 	train_h1_row_norms_max: 1.16293859482
# 	train_h1_row_norms_mean: 1.00707542896
# 	train_h1_row_norms_min: 0.864998340607
# 	train_objective: 2.26396894455
# 	train_y_col_norms_max: 0.11124061048
# 	train_y_col_norms_mean: 0.0754992589355
# 	train_y_col_norms_min: 0.053731944412
# 	train_y_max_max_class: 0.115357078612
# 	train_y_mean_max_class: 0.106709964573
# 	train_y_min_max_class: 0.102847002447
# 	train_y_misclass: 0.569999992847
# 	train_y_nll: 2.26396894455
# 	train_y_row_norms_max: 0.0558791719377
# 	train_y_row_norms_mean: 0.0203072223812
# 	train_y_row_norms_min: 0.00219676503912
# 	training_seconds_this_epoch: 0.0765039995313
# Time this epoch: 0.079490 seconds
# Monitoring step:
# 	Epochs seen: 2
# 	Batches seen: 20
# 	Examples seen: 2000
# 	learning_rate: 0.099999986589
# 	momentum: 0.500000059605
# 	test_h0_col_norms_max: 1.06305730343
# 	test_h0_col_norms_mean: 1.00336956978
# 	test_h0_col_norms_min: 0.940306901932
# 	test_h0_max_x_max_u: 1.83217453957
# 	test_h0_max_x_mean_u: 0.77869194746
# 	test_h0_max_x_min_u: 0.0376306697726
# 	test_h0_mean_x_max_u: 0.814771950245
# 	test_h0_mean_x_mean_u: 0.189053744078
# 	test_h0_mean_x_min_u: 0.000595318269916
# 	test_h0_min_x_max_u: 0.151219651103
# 	test_h0_min_x_mean_u: 0.00151219638065
# 	test_h0_min_x_min_u: 0.0
# 	test_h0_range_x_max_u: 1.81660676003
# 	test_h0_range_x_mean_u: 0.777179718018
# 	test_h0_range_x_min_u: 0.0376306697726
# 	test_h0_row_norms_max: 0.436813563108
# 	test_h0_row_norms_mean: 0.357498139143
# 	test_h0_row_norms_min: 0.280473798513
# 	test_h1_col_norms_max: 1.20968019962
# 	test_h1_col_norms_mean: 1.00822615623
# 	test_h1_col_norms_min: 0.809271395206
# 	test_h1_max_x_max_u: 1.69195461273
# 	test_h1_max_x_mean_u: 0.57115894556
# 	test_h1_max_x_min_u: 0.0
# 	test_h1_mean_x_max_u: 0.546870112419
# 	test_h1_mean_x_mean_u: 0.151245683432
# 	test_h1_mean_x_min_u: 0.0
# 	test_h1_min_x_max_u: 0.0247348379344
# 	test_h1_min_x_mean_u: 0.000320939114317
# 	test_h1_min_x_min_u: 0.0
# 	test_h1_range_x_max_u: 1.69195461273
# 	test_h1_range_x_mean_u: 0.570838034153
# 	test_h1_range_x_min_u: 0.0
# 	test_h1_row_norms_max: 1.16397964954
# 	test_h1_row_norms_mean: 1.00838541985
# 	test_h1_row_norms_min: 0.867279112339
# 	test_objective: 2.14843034744
# 	test_y_col_norms_max: 0.294056743383
# 	test_y_col_norms_mean: 0.183990433812
# 	test_y_col_norms_min: 0.118449114263
# 	test_y_max_max_class: 0.216087907553
# 	test_y_mean_max_class: 0.128736883402
# 	test_y_min_max_class: 0.106923222542
# 	test_y_misclass: 0.575000047684
# 	test_y_nll: 2.14843034744
# 	test_y_row_norms_max: 0.150932133198
# 	test_y_row_norms_mean: 0.0488044582307
# 	test_y_row_norms_min: 0.00257564499043
# 	total_seconds_last_epoch: 0.399715006351
# 	train_h0_col_norms_max: 1.06305730343
# 	train_h0_col_norms_mean: 1.00336956978
# 	train_h0_col_norms_min: 0.940306901932
# 	train_h0_max_x_max_u: 1.80534744263
# 	train_h0_max_x_mean_u: 0.761926949024
# 	train_h0_max_x_min_u: 0.0509638041258
# 	train_h0_mean_x_max_u: 0.787827193737
# 	train_h0_mean_x_mean_u: 0.185498431325
# 	train_h0_mean_x_min_u: 0.000702115881722
# 	train_h0_min_x_max_u: 0.136133059859
# 	train_h0_min_x_mean_u: 0.00137102941517
# 	train_h0_min_x_min_u: 0.0
# 	train_h0_range_x_max_u: 1.80470275879
# 	train_h0_range_x_mean_u: 0.760555803776
# 	train_h0_range_x_min_u: 0.0509638041258
# 	train_h0_row_norms_max: 0.436813563108
# 	train_h0_row_norms_mean: 0.357498139143
# 	train_h0_row_norms_min: 0.280473798513
# 	train_h1_col_norms_max: 1.20968019962
# 	train_h1_col_norms_mean: 1.00822615623
# 	train_h1_col_norms_min: 0.809271395206
# 	train_h1_max_x_max_u: 1.57231628895
# 	train_h1_max_x_mean_u: 0.559122443199
# 	train_h1_max_x_min_u: 0.0
# 	train_h1_mean_x_max_u: 0.537385642529
# 	train_h1_mean_x_mean_u: 0.149182394147
# 	train_h1_mean_x_min_u: 0.0
# 	train_h1_min_x_max_u: 0.0360823534429
# 	train_h1_min_x_mean_u: 0.000581309897825
# 	train_h1_min_x_min_u: 0.0
# 	train_h1_range_x_max_u: 1.5697991848
# 	train_h1_range_x_mean_u: 0.558541119099
# 	train_h1_range_x_min_u: 0.0
# 	train_h1_row_norms_max: 1.16397964954
# 	train_h1_row_norms_mean: 1.00838541985
# 	train_h1_row_norms_min: 0.867279112339
# 	train_objective: 2.13573145866
# 	train_y_col_norms_max: 0.294056743383
# 	train_y_col_norms_mean: 0.183990433812
# 	train_y_col_norms_min: 0.118449114263
# 	train_y_max_max_class: 0.215124756098
# 	train_y_mean_max_class: 0.129534035921
# 	train_y_min_max_class: 0.106335677207
# 	train_y_misclass: 0.583000004292
# 	train_y_nll: 2.13573145866
# 	train_y_row_norms_max: 0.150932133198
# 	train_y_row_norms_mean: 0.0488044582307
# 	train_y_row_norms_min: 0.00257564499043
# 	training_seconds_this_epoch: 0.0794900134206
# Time this epoch: 0.076567 seconds
# Monitoring step:
# 	Epochs seen: 3
# 	Batches seen: 30
# 	Examples seen: 3000
# 	learning_rate: 0.099999986589
# 	momentum: 0.500000059605
# 	test_h0_col_norms_max: 1.06711316109
# 	test_h0_col_norms_mean: 1.00860762596
# 	test_h0_col_norms_min: 0.940884590149
# 	test_h0_max_x_max_u: 2.83095693588
# 	test_h0_max_x_mean_u: 1.0667951107
# 	test_h0_max_x_min_u: 0.0395365096629
# 	test_h0_mean_x_max_u: 1.28329873085
# 	test_h0_mean_x_mean_u: 0.313957154751
# 	test_h0_mean_x_min_u: 0.000608601199929
# 	test_h0_min_x_max_u: 0.344574779272
# 	test_h0_min_x_mean_u: 0.00428696768358
# 	test_h0_min_x_min_u: 0.0
# 	test_h0_range_x_max_u: 2.82145404816
# 	test_h0_range_x_mean_u: 1.06250810623
# 	test_h0_range_x_min_u: 0.0395365096629
# 	test_h0_row_norms_max: 0.436746716499
# 	test_h0_row_norms_mean: 0.359357297421
# 	test_h0_row_norms_min: 0.280473798513
# 	test_h1_col_norms_max: 1.21659326553
# 	test_h1_col_norms_mean: 1.01306569576
# 	test_h1_col_norms_min: 0.816726148129
# 	test_h1_max_x_max_u: 3.33260345459
# 	test_h1_max_x_mean_u: 0.982680439949
# 	test_h1_max_x_min_u: 0.0
# 	test_h1_mean_x_max_u: 1.02735197544
# 	test_h1_mean_x_mean_u: 0.287164062262
# 	test_h1_mean_x_min_u: 0.0
# 	test_h1_min_x_max_u: 0.0588113293052
# 	test_h1_min_x_mean_u: 0.000941264093854
# 	test_h1_min_x_min_u: 0.0
# 	test_h1_range_x_max_u: 3.33260345459
# 	test_h1_range_x_mean_u: 0.981739163399
# 	test_h1_range_x_min_u: 0.0
# 	test_h1_row_norms_max: 1.17268562317
# 	test_h1_row_norms_mean: 1.01328611374
# 	test_h1_row_norms_min: 0.875302016735
# 	test_objective: 1.7220890522
# 	test_y_col_norms_max: 0.57018661499
# 	test_y_col_norms_mean: 0.368319630623
# 	test_y_col_norms_min: 0.212889477611
# 	test_y_max_max_class: 0.649778485298
# 	test_y_mean_max_class: 0.22110798955
# 	test_y_min_max_class: 0.120734199882
# 	test_y_misclass: 0.408999979496
# 	test_y_nll: 1.7220890522
# 	test_y_row_norms_max: 0.283712416887
# 	test_y_row_norms_mean: 0.0966741219163
# 	test_y_row_norms_min: 0.00265311892144
# 	total_seconds_last_epoch: 0.39892795682
# 	train_h0_col_norms_max: 1.06711316109
# 	train_h0_col_norms_mean: 1.00860762596
# 	train_h0_col_norms_min: 0.940884590149
# 	train_h0_max_x_max_u: 2.80888795853
# 	train_h0_max_x_mean_u: 1.04323256016
# 	train_h0_max_x_min_u: 0.0423219464719
# 	train_h0_mean_x_max_u: 1.27551007271
# 	train_h0_mean_x_mean_u: 0.30756020546
# 	train_h0_mean_x_min_u: 0.000561867607757
# 	train_h0_min_x_max_u: 0.331990122795
# 	train_h0_min_x_mean_u: 0.00414318405092
# 	train_h0_min_x_min_u: 0.0
# 	train_h0_range_x_max_u: 2.80888795853
# 	train_h0_range_x_mean_u: 1.0390894413
# 	train_h0_range_x_min_u: 0.0423219464719
# 	train_h0_row_norms_max: 0.436746716499
# 	train_h0_row_norms_mean: 0.359357297421
# 	train_h0_row_norms_min: 0.280473798513
# 	train_h1_col_norms_max: 1.21659326553
# 	train_h1_col_norms_mean: 1.01306569576
# 	train_h1_col_norms_min: 0.816726148129
# 	train_h1_max_x_max_u: 3.0735347271
# 	train_h1_max_x_mean_u: 0.962003052235
# 	train_h1_max_x_min_u: 0.0
# 	train_h1_mean_x_max_u: 0.984959363937
# 	train_h1_mean_x_mean_u: 0.283362656832
# 	train_h1_mean_x_min_u: 0.0
# 	train_h1_min_x_max_u: 0.0628297924995
# 	train_h1_min_x_mean_u: 0.000931099057198
# 	train_h1_min_x_min_u: 0.0
# 	train_h1_range_x_max_u: 3.0735347271
# 	train_h1_range_x_mean_u: 0.961071968079
# 	train_h1_range_x_min_u: 0.0
# 	train_h1_row_norms_max: 1.17268562317
# 	train_h1_row_norms_mean: 1.01328611374
# 	train_h1_row_norms_min: 0.875302016735
# 	train_objective: 1.68255245686
# 	train_y_col_norms_max: 0.57018661499
# 	train_y_col_norms_mean: 0.368319630623
# 	train_y_col_norms_min: 0.212889477611
# 	train_y_max_max_class: 0.660824656487
# 	train_y_mean_max_class: 0.226250484586
# 	train_y_min_max_class: 0.118295103312
# 	train_y_misclass: 0.373000025749
# 	train_y_nll: 1.68255245686
# 	train_y_row_norms_max: 0.283712416887
# 	train_y_row_norms_mean: 0.0966741219163
# 	train_y_row_norms_min: 0.00265311892144
# 	training_seconds_this_epoch: 0.0765670016408
# Time this epoch: 0.076755 seconds
# Monitoring step:
# 	Epochs seen: 4
# 	Batches seen: 40
# 	Examples seen: 4000
# 	learning_rate: 0.099999986589
# 	momentum: 0.500000059605
# 	test_h0_col_norms_max: 1.11460793018
# 	test_h0_col_norms_mean: 1.01910960674
# 	test_h0_col_norms_min: 0.943947970867
# 	test_h0_max_x_max_u: 4.03108596802
# 	test_h0_max_x_mean_u: 1.44839954376
# 	test_h0_max_x_min_u: 0.0350178405643
# 	test_h0_mean_x_max_u: 1.80931425095
# 	test_h0_mean_x_mean_u: 0.476316422224
# 	test_h0_mean_x_min_u: 0.00059692573268
# 	test_h0_min_x_max_u: 0.536396503448
# 	test_h0_min_x_mean_u: 0.00886026769876
# 	test_h0_min_x_min_u: 0.0
# 	test_h0_range_x_max_u: 4.0198469162
# 	test_h0_range_x_mean_u: 1.43953919411
# 	test_h0_range_x_min_u: 0.0350178405643
# 	test_h0_row_norms_max: 0.443038374186
# 	test_h0_row_norms_mean: 0.363063722849
# 	test_h0_row_norms_min: 0.280473798513
# 	test_h1_col_norms_max: 1.23125362396
# 	test_h1_col_norms_mean: 1.02282571793
# 	test_h1_col_norms_min: 0.831244647503
# 	test_h1_max_x_max_u: 5.4942908287
# 	test_h1_max_x_mean_u: 1.63247060776
# 	test_h1_max_x_min_u: 0.0
# 	test_h1_mean_x_max_u: 1.69427454472
# 	test_h1_mean_x_mean_u: 0.516746878624
# 	test_h1_mean_x_min_u: 0.0
# 	test_h1_min_x_max_u: 0.0896493941545
# 	test_h1_min_x_mean_u: 0.00180161022581
# 	test_h1_min_x_min_u: 0.0
# 	test_h1_range_x_max_u: 5.4942908287
# 	test_h1_range_x_mean_u: 1.63066899776
# 	test_h1_range_x_min_u: 0.0
# 	test_h1_row_norms_max: 1.19547796249
# 	test_h1_row_norms_mean: 1.02314937115
# 	test_h1_row_norms_min: 0.889712035656
# 	test_objective: 1.15405845642
# 	test_y_col_norms_max: 0.821692407131
# 	test_y_col_norms_mean: 0.59273904562
# 	test_y_col_norms_min: 0.367552161217
# 	test_y_max_max_class: 0.93451744318
# 	test_y_mean_max_class: 0.406836867332
# 	test_y_min_max_class: 0.156486883759
# 	test_y_misclass: 0.288999974728
# 	test_y_nll: 1.15405845642
# 	test_y_row_norms_max: 0.399145454168
# 	test_y_row_norms_mean: 0.153999328613
# 	test_y_row_norms_min: 0.00266336160712
# 	total_seconds_last_epoch: 0.391640037298
# 	train_h0_col_norms_max: 1.11460793018
# 	train_h0_col_norms_mean: 1.01910960674
# 	train_h0_col_norms_min: 0.943947970867
# 	train_h0_max_x_max_u: 3.86370563507
# 	train_h0_max_x_mean_u: 1.41748452187
# 	train_h0_max_x_min_u: 0.0320980213583
# 	train_h0_mean_x_max_u: 1.78839421272
# 	train_h0_mean_x_mean_u: 0.465445041656
# 	train_h0_mean_x_min_u: 0.000428176659625
# 	train_h0_min_x_max_u: 0.533168613911
# 	train_h0_min_x_mean_u: 0.00889937113971
# 	train_h0_min_x_min_u: 0.0
# 	train_h0_range_x_max_u: 3.86141324043
# 	train_h0_range_x_mean_u: 1.40858519077
# 	train_h0_range_x_min_u: 0.0320980213583
# 	train_h0_row_norms_max: 0.443038374186
# 	train_h0_row_norms_mean: 0.363063722849
# 	train_h0_row_norms_min: 0.280473798513
# 	train_h1_col_norms_max: 1.23125362396
# 	train_h1_col_norms_mean: 1.02282571793
# 	train_h1_col_norms_min: 0.831244647503
# 	train_h1_max_x_max_u: 5.08467340469
# 	train_h1_max_x_mean_u: 1.5936088562
# 	train_h1_max_x_min_u: 0.0
# 	train_h1_mean_x_max_u: 1.67192387581
# 	train_h1_mean_x_mean_u: 0.508422672749
# 	train_h1_mean_x_min_u: 0.0
# 	train_h1_min_x_max_u: 0.101231276989
# 	train_h1_min_x_mean_u: 0.0018501750892
# 	train_h1_min_x_min_u: 0.0
# 	train_h1_range_x_max_u: 5.08467340469
# 	train_h1_range_x_mean_u: 1.59175896645
# 	train_h1_range_x_min_u: 0.0
# 	train_h1_row_norms_max: 1.19547796249
# 	train_h1_row_norms_mean: 1.02314937115
# 	train_h1_row_norms_min: 0.889712035656
# 	train_objective: 1.06958007812
# 	train_y_col_norms_max: 0.821692407131
# 	train_y_col_norms_mean: 0.59273904562
# 	train_y_col_norms_min: 0.367552161217
# 	train_y_max_max_class: 0.939358353615
# 	train_y_mean_max_class: 0.427326142788
# 	train_y_min_max_class: 0.152194455266
# 	train_y_misclass: 0.230999976397
# 	train_y_nll: 1.06958007812
# 	train_y_row_norms_max: 0.399145454168
# 	train_y_row_norms_mean: 0.153999328613
# 	train_y_row_norms_min: 0.00266336160712
# 	training_seconds_this_epoch: 0.0767549946904
# Time this epoch: 0.076340 seconds
# Monitoring step:
# 	Epochs seen: 5
# 	Batches seen: 50
# 	Examples seen: 5000
# 	learning_rate: 0.099999986589
# 	momentum: 0.500000059605
# 	test_h0_col_norms_max: 1.14932739735
# 	test_h0_col_norms_mean: 1.02921593189
# 	test_h0_col_norms_min: 0.947646379471
# 	test_h0_max_x_max_u: 4.65499973297
# 	test_h0_max_x_mean_u: 1.69929552078
# 	test_h0_max_x_min_u: 0.0342949405313
# 	test_h0_mean_x_max_u: 2.08451151848
# 	test_h0_mean_x_mean_u: 0.575312197208
# 	test_h0_mean_x_min_u: 0.000570055155549
# 	test_h0_min_x_max_u: 0.607917308807
# 	test_h0_min_x_mean_u: 0.0106261633337
# 	test_h0_min_x_min_u: 0.0
# 	test_h0_range_x_max_u: 4.64167976379
# 	test_h0_range_x_mean_u: 1.68866920471
# 	test_h0_range_x_min_u: 0.0342949405313
# 	test_h0_row_norms_max: 0.45808044076
# 	test_h0_row_norms_mean: 0.366596549749
# 	test_h0_row_norms_min: 0.280473798513
# 	test_h1_col_norms_max: 1.24947822094
# 	test_h1_col_norms_mean: 1.0322893858
# 	test_h1_col_norms_min: 0.845647394657
# 	test_h1_max_x_max_u: 6.84989500046
# 	test_h1_max_x_mean_u: 2.11669826508
# 	test_h1_max_x_min_u: 0.0
# 	test_h1_mean_x_max_u: 2.13412213326
# 	test_h1_mean_x_mean_u: 0.684898376465
# 	test_h1_mean_x_min_u: 0.0
# 	test_h1_min_x_max_u: 0.142428070307
# 	test_h1_min_x_mean_u: 0.00252998713404
# 	test_h1_min_x_min_u: 0.0
# 	test_h1_range_x_max_u: 6.84989500046
# 	test_h1_range_x_mean_u: 2.11416840553
# 	test_h1_range_x_min_u: 0.0
# 	test_h1_row_norms_max: 1.21548783779
# 	test_h1_row_norms_mean: 1.03275668621
# 	test_h1_row_norms_min: 0.889980256557
# 	test_objective: 0.834180235863
# 	test_y_col_norms_max: 1.00634145737
# 	test_y_col_norms_mean: 0.751444160938
# 	test_y_col_norms_min: 0.522492587566
# 	test_y_max_max_class: 0.980666279793
# 	test_y_mean_max_class: 0.581911981106
# 	test_y_min_max_class: 0.200448006392
# 	test_y_misclass: 0.237000003457
# 	test_y_nll: 0.834180235863
# 	test_y_row_norms_max: 0.486268281937
# 	test_y_row_norms_mean: 0.195263013244
# 	test_y_row_norms_min: 0.00266337138601
# 	total_seconds_last_epoch: 0.391252964735
# 	train_h0_col_norms_max: 1.14932739735
# 	train_h0_col_norms_mean: 1.02921593189
# 	train_h0_col_norms_min: 0.947646379471
# 	train_h0_max_x_max_u: 4.44496536255
# 	train_h0_max_x_mean_u: 1.66401827335
# 	train_h0_max_x_min_u: 0.0278791002929
# 	train_h0_mean_x_max_u: 2.05176591873
# 	train_h0_mean_x_mean_u: 0.561449885368
# 	train_h0_mean_x_min_u: 0.00037754495861
# 	train_h0_min_x_max_u: 0.61878490448
# 	train_h0_min_x_mean_u: 0.0100459652022
# 	train_h0_min_x_min_u: 0.0
# 	train_h0_range_x_max_u: 4.43668365479
# 	train_h0_range_x_mean_u: 1.65397238731
# 	train_h0_range_x_min_u: 0.0278791002929
# 	train_h0_row_norms_max: 0.45808044076
# 	train_h0_row_norms_mean: 0.366596549749
# 	train_h0_row_norms_min: 0.280473798513
# 	train_h1_col_norms_max: 1.24947822094
# 	train_h1_col_norms_mean: 1.0322893858
# 	train_h1_col_norms_min: 0.845647394657
# 	train_h1_max_x_max_u: 6.43478679657
# 	train_h1_max_x_mean_u: 2.06896901131
# 	train_h1_max_x_min_u: 0.0
# 	train_h1_mean_x_max_u: 2.11113262177
# 	train_h1_mean_x_mean_u: 0.672600626945
# 	train_h1_mean_x_min_u: 0.0
# 	train_h1_min_x_max_u: 0.181353420019
# 	train_h1_min_x_mean_u: 0.00286162574776
# 	train_h1_min_x_min_u: 0.0
# 	train_h1_range_x_max_u: 6.43478679657
# 	train_h1_range_x_mean_u: 2.06610751152
# 	train_h1_range_x_min_u: 0.0
# 	train_h1_row_norms_max: 1.21548783779
# 	train_h1_row_norms_mean: 1.03275668621
# 	train_h1_row_norms_min: 0.889980256557
# 	train_objective: 0.727973520756
# 	train_y_col_norms_max: 1.00634145737
# 	train_y_col_norms_mean: 0.751444160938
# 	train_y_col_norms_min: 0.522492587566
# 	train_y_max_max_class: 0.978774309158
# 	train_y_mean_max_class: 0.610808432102
# 	train_y_min_max_class: 0.19889087975
# 	train_y_misclass: 0.197999984026
# 	train_y_nll: 0.727973520756
# 	train_y_row_norms_max: 0.486268281937
# 	train_y_row_norms_mean: 0.195263013244
# 	train_y_row_norms_min: 0.00266337138601
# 	training_seconds_this_epoch: 0.0763399973512
# Saving to ./model_mnist.pkl...
# Saving to ./model_mnist.pkl done. Time elapsed: 0.280740 seconds
# Time this epoch: 0.076995 seconds
# Monitoring step:
# 	Epochs seen: 6
# 	Batches seen: 60
# 	Examples seen: 6000
# 	learning_rate: 0.099999986589
# 	momentum: 0.500000059605
# 	test_h0_col_norms_max: 1.16920340061
# 	test_h0_col_norms_mean: 1.03661429882
# 	test_h0_col_norms_min: 0.950977563858
# 	test_h0_max_x_max_u: 5.02766466141
# 	test_h0_max_x_mean_u: 1.83139204979
# 	test_h0_max_x_min_u: 0.0397325791419
# 	test_h0_mean_x_max_u: 2.27318048477
# 	test_h0_mean_x_mean_u: 0.623455286026
# 	test_h0_mean_x_min_u: 0.000664046092425
# 	test_h0_min_x_max_u: 0.62577098608
# 	test_h0_min_x_mean_u: 0.0116202309728
# 	test_h0_min_x_min_u: 0.0
# 	test_h0_range_x_max_u: 5.01301288605
# 	test_h0_range_x_mean_u: 1.81977188587
# 	test_h0_range_x_min_u: 0.0397325791419
# 	test_h0_row_norms_max: 0.472008615732
# 	test_h0_row_norms_mean: 0.369161456823
# 	test_h0_row_norms_min: 0.280473798513
# 	test_h1_col_norms_max: 1.26524698734
# 	test_h1_col_norms_mean: 1.03916871548
# 	test_h1_col_norms_min: 0.853746473789
# 	test_h1_max_x_max_u: 7.66941070557
# 	test_h1_max_x_mean_u: 2.3909034729
# 	test_h1_max_x_min_u: 0.0
# 	test_h1_mean_x_max_u: 2.43283319473
# 	test_h1_mean_x_mean_u: 0.77819788456
# 	test_h1_mean_x_min_u: 0.0
# 	test_h1_min_x_max_u: 0.0850924924016
# 	test_h1_min_x_mean_u: 0.00154214771464
# 	test_h1_min_x_min_u: 0.0
# 	test_h1_range_x_max_u: 7.66941070557
# 	test_h1_range_x_mean_u: 2.38936161995
# 	test_h1_range_x_min_u: 0.0
# 	test_h1_row_norms_max: 1.22704899311
# 	test_h1_row_norms_mean: 1.03975486755
# 	test_h1_row_norms_min: 0.890263557434
# 	test_objective: 0.714465558529
# 	test_y_col_norms_max: 1.12016665936
# 	test_y_col_norms_mean: 0.851332485676
# 	test_y_col_norms_min: 0.62745475769
# 	test_y_max_max_class: 0.991564691067
# 	test_y_mean_max_class: 0.673109650612
# 	test_y_min_max_class: 0.247116580606
# 	test_y_misclass: 0.203999981284
# 	test_y_nll: 0.714465558529
# 	test_y_row_norms_max: 0.559674739838
# 	test_y_row_norms_mean: 0.22137606144
# 	test_y_row_norms_min: 0.00266337138601
# 	total_seconds_last_epoch: 0.674911916256
# 	train_h0_col_norms_max: 1.16920340061
# 	train_h0_col_norms_mean: 1.03661429882
# 	train_h0_col_norms_min: 0.950977563858
# 	train_h0_max_x_max_u: 4.77302360535
# 	train_h0_max_x_mean_u: 1.79474043846
# 	train_h0_max_x_min_u: 0.0351286865771
# 	train_h0_mean_x_max_u: 2.22935128212
# 	train_h0_mean_x_mean_u: 0.608126759529
# 	train_h0_mean_x_min_u: 0.000505105941556
# 	train_h0_min_x_max_u: 0.64672935009
# 	train_h0_min_x_mean_u: 0.0102401375771
# 	train_h0_min_x_min_u: 0.0
# 	train_h0_range_x_max_u: 4.76895236969
# 	train_h0_range_x_mean_u: 1.78450036049
# 	train_h0_range_x_min_u: 0.0351286865771
# 	train_h0_row_norms_max: 0.472008615732
# 	train_h0_row_norms_mean: 0.369161456823
# 	train_h0_row_norms_min: 0.280473798513
# 	train_h1_col_norms_max: 1.26524698734
# 	train_h1_col_norms_mean: 1.03916871548
# 	train_h1_col_norms_min: 0.853746473789
# 	train_h1_max_x_max_u: 7.28800201416
# 	train_h1_max_x_mean_u: 2.3407292366
# 	train_h1_max_x_min_u: 0.0
# 	train_h1_mean_x_max_u: 2.40500187874
# 	train_h1_mean_x_mean_u: 0.763260304928
# 	train_h1_mean_x_min_u: 0.0
# 	train_h1_min_x_max_u: 0.0953525155783
# 	train_h1_min_x_mean_u: 0.00115710240789
# 	train_h1_min_x_min_u: 0.0
# 	train_h1_range_x_max_u: 7.28651809692
# 	train_h1_range_x_mean_u: 2.33957195282
# 	train_h1_range_x_min_u: 0.0
# 	train_h1_row_norms_max: 1.22704899311
# 	train_h1_row_norms_mean: 1.03975486755
# 	train_h1_row_norms_min: 0.890263557434
# 	train_objective: 0.577620565891
# 	train_y_col_norms_max: 1.12016665936
# 	train_y_col_norms_mean: 0.851332485676
# 	train_y_col_norms_min: 0.62745475769
# 	train_y_max_max_class: 0.989890098572
# 	train_y_mean_max_class: 0.705089151859
# 	train_y_min_max_class: 0.240849375725
# 	train_y_misclass: 0.157000005245
# 	train_y_nll: 0.577620565891
# 	train_y_row_norms_max: 0.559674739838
# 	train_y_row_norms_mean: 0.22137606144
# 	train_y_row_norms_min: 0.00266337138601
# 	training_seconds_this_epoch: 0.0769950002432
# Time this epoch: 0.077085 seconds
# Monitoring step:
# 	Epochs seen: 7
# 	Batches seen: 70
# 	Examples seen: 7000
# 	learning_rate: 0.099999986589
# 	momentum: 0.500000059605
# 	test_h0_col_norms_max: 1.17077636719
# 	test_h0_col_norms_mean: 1.042345047
# 	test_h0_col_norms_min: 0.954309046268
# 	test_h0_max_x_max_u: 4.94107437134
# 	test_h0_max_x_mean_u: 1.90625333786
# 	test_h0_max_x_min_u: 0.0462045930326
# 	test_h0_mean_x_max_u: 2.15502882004
# 	test_h0_mean_x_mean_u: 0.647934436798
# 	test_h0_mean_x_min_u: 0.00081706547644
# 	test_h0_min_x_max_u: 0.615577101707
# 	test_h0_min_x_mean_u: 0.0103767225519
# 	test_h0_min_x_min_u: 0.0
# 	test_h0_range_x_max_u: 4.93711090088
# 	test_h0_range_x_mean_u: 1.89587628841
# 	test_h0_range_x_min_u: 0.0462045930326
# 	test_h0_row_norms_max: 0.47823575139
# 	test_h0_row_norms_mean: 0.371127814054
# 	test_h0_row_norms_min: 0.280473798513
# 	test_h1_col_norms_max: 1.27824509144
# 	test_h1_col_norms_mean: 1.04432523251
# 	test_h1_col_norms_min: 0.861365139484
# 	test_h1_max_x_max_u: 7.76571750641
# 	test_h1_max_x_mean_u: 2.5423271656
# 	test_h1_max_x_min_u: 0.0
# 	test_h1_mean_x_max_u: 2.43446969986
# 	test_h1_mean_x_mean_u: 0.814803242683
# 	test_h1_mean_x_min_u: 0.0
# 	test_h1_min_x_max_u: 0.05322836712
# 	test_h1_min_x_mean_u: 0.000682621437591
# 	test_h1_min_x_min_u: 0.0
# 	test_h1_range_x_max_u: 7.76571750641
# 	test_h1_range_x_mean_u: 2.54164457321
# 	test_h1_range_x_min_u: 0.0
# 	test_h1_row_norms_max: 1.23856174946
# 	test_h1_row_norms_mean: 1.04502367973
# 	test_h1_row_norms_min: 0.890461206436
# 	test_objective: 0.613446354866
# 	test_y_col_norms_max: 1.17661118507
# 	test_y_col_norms_mean: 0.922674536705
# 	test_y_col_norms_min: 0.691035449505
# 	test_y_max_max_class: 0.997032165527
# 	test_y_mean_max_class: 0.724932789803
# 	test_y_min_max_class: 0.256317406893
# 	test_y_misclass: 0.18599998951
# 	test_y_nll: 0.613446354866
# 	test_y_row_norms_max: 0.606767475605
# 	test_y_row_norms_mean: 0.240113765001
# 	test_y_row_norms_min: 0.00266337138601
# 	total_seconds_last_epoch: 0.390940010548
# 	train_h0_col_norms_max: 1.17077636719
# 	train_h0_col_norms_mean: 1.042345047
# 	train_h0_col_norms_min: 0.954309046268
# 	train_h0_max_x_max_u: 4.79293251038
# 	train_h0_max_x_mean_u: 1.86645793915
# 	train_h0_max_x_min_u: 0.0428738966584
# 	train_h0_mean_x_max_u: 2.10996413231
# 	train_h0_mean_x_mean_u: 0.631803154945
# 	train_h0_mean_x_min_u: 0.000632651848719
# 	train_h0_min_x_max_u: 0.635077476501
# 	train_h0_min_x_mean_u: 0.00887346547097
# 	train_h0_min_x_min_u: 0.0
# 	train_h0_range_x_max_u: 4.78711128235
# 	train_h0_range_x_mean_u: 1.85758447647
# 	train_h0_range_x_min_u: 0.0428738966584
# 	train_h0_row_norms_max: 0.47823575139
# 	train_h0_row_norms_mean: 0.371127814054
# 	train_h0_row_norms_min: 0.280473798513
# 	train_h1_col_norms_max: 1.27824509144
# 	train_h1_col_norms_mean: 1.04432523251
# 	train_h1_col_norms_min: 0.861365139484
# 	train_h1_max_x_max_u: 7.52039861679
# 	train_h1_max_x_mean_u: 2.48978161812
# 	train_h1_max_x_min_u: 0.0
# 	train_h1_mean_x_max_u: 2.4125893116
# 	train_h1_mean_x_mean_u: 0.799419045448
# 	train_h1_mean_x_min_u: 0.0
# 	train_h1_min_x_max_u: 0.0693615972996
# 	train_h1_min_x_mean_u: 0.000934896816034
# 	train_h1_min_x_min_u: 0.0
# 	train_h1_range_x_max_u: 7.52039861679
# 	train_h1_range_x_mean_u: 2.48884677887
# 	train_h1_range_x_min_u: 0.0
# 	train_h1_row_norms_max: 1.23856174946
# 	train_h1_row_norms_mean: 1.04502367973
# 	train_h1_row_norms_min: 0.890461206436
# 	train_objective: 0.468716025352
# 	train_y_col_norms_max: 1.17661118507
# 	train_y_col_norms_mean: 0.922674536705
# 	train_y_col_norms_min: 0.691035449505
# 	train_y_max_max_class: 0.996845006943
# 	train_y_mean_max_class: 0.761720895767
# 	train_y_min_max_class: 0.252530395985
# 	train_y_misclass: 0.130999997258
# 	train_y_nll: 0.468716025352
# 	train_y_row_norms_max: 0.606767475605
# 	train_y_row_norms_mean: 0.240113765001
# 	train_y_row_norms_min: 0.00266337138601
# 	training_seconds_this_epoch: 0.0770850032568
# Time this epoch: 0.076852 seconds
# Monitoring step:
# 	Epochs seen: 8
# 	Batches seen: 80
# 	Examples seen: 8000
# 	learning_rate: 0.099999986589
# 	momentum: 0.500000059605
# 	test_h0_col_norms_max: 1.1883585453
# 	test_h0_col_norms_mean: 1.04716253281
# 	test_h0_col_norms_min: 0.95645314455
# 	test_h0_max_x_max_u: 5.18693971634
# 	test_h0_max_x_mean_u: 1.95527303219
# 	test_h0_max_x_min_u: 0.0574900060892
# 	test_h0_mean_x_max_u: 2.30134701729
# 	test_h0_mean_x_mean_u: 0.663498818874
# 	test_h0_mean_x_min_u: 0.00122210860718
# 	test_h0_min_x_max_u: 0.60200715065
# 	test_h0_min_x_mean_u: 0.0111785950139
# 	test_h0_min_x_min_u: 0.0
# 	test_h0_range_x_max_u: 5.17663192749
# 	test_h0_range_x_mean_u: 1.94409441948
# 	test_h0_range_x_min_u: 0.0574900060892
# 	test_h0_row_norms_max: 0.488236308098
# 	test_h0_row_norms_mean: 0.372778385878
# 	test_h0_row_norms_min: 0.280473798513
# 	test_h1_col_norms_max: 1.28770697117
# 	test_h1_col_norms_mean: 1.04868757725
# 	test_h1_col_norms_min: 0.866229593754
# 	test_h1_max_x_max_u: 8.15259933472
# 	test_h1_max_x_mean_u: 2.66557407379
# 	test_h1_max_x_min_u: 0.0
# 	test_h1_mean_x_max_u: 2.57336997986
# 	test_h1_mean_x_mean_u: 0.853820800781
# 	test_h1_mean_x_min_u: 0.0
# 	test_h1_min_x_max_u: 0.0631824657321
# 	test_h1_min_x_mean_u: 0.000758003152441
# 	test_h1_min_x_min_u: 0.0
# 	test_h1_range_x_max_u: 8.15259933472
# 	test_h1_range_x_mean_u: 2.66481590271
# 	test_h1_range_x_min_u: 0.0
# 	test_h1_row_norms_max: 1.24253559113
# 	test_h1_row_norms_mean: 1.04946482182
# 	test_h1_row_norms_min: 0.890857934952
# 	test_objective: 0.549885928631
# 	test_y_col_norms_max: 1.22743856907
# 	test_y_col_norms_mean: 0.978164553642
# 	test_y_col_norms_min: 0.755949676037
# 	test_y_max_max_class: 0.997386872768
# 	test_y_mean_max_class: 0.763035237789
# 	test_y_min_max_class: 0.26855763793
# 	test_y_misclass: 0.154999986291
# 	test_y_nll: 0.549885928631
# 	test_y_row_norms_max: 0.64081287384
# 	test_y_row_norms_mean: 0.254772484303
# 	test_y_row_norms_min: 0.00266337138601
# 	total_seconds_last_epoch: 0.392641991377
# 	train_h0_col_norms_max: 1.1883585453
# 	train_h0_col_norms_mean: 1.04716253281
# 	train_h0_col_norms_min: 0.95645314455
# 	train_h0_max_x_max_u: 5.00512981415
# 	train_h0_max_x_mean_u: 1.91368103027
# 	train_h0_max_x_min_u: 0.0560524612665
# 	train_h0_mean_x_max_u: 2.24890422821
# 	train_h0_mean_x_mean_u: 0.646934449673
# 	train_h0_mean_x_min_u: 0.000873918936122
# 	train_h0_min_x_max_u: 0.620710134506
# 	train_h0_min_x_mean_u: 0.00883941538632
# 	train_h0_min_x_min_u: 0.0
# 	train_h0_range_x_max_u: 4.9994802475
# 	train_h0_range_x_mean_u: 1.90484189987
# 	train_h0_range_x_min_u: 0.0560524612665
# 	train_h0_row_norms_max: 0.488236308098
# 	train_h0_row_norms_mean: 0.372778385878
# 	train_h0_row_norms_min: 0.280473798513
# 	train_h1_col_norms_max: 1.28770697117
# 	train_h1_col_norms_mean: 1.04868757725
# 	train_h1_col_norms_min: 0.866229593754
# 	train_h1_max_x_max_u: 7.88111543655
# 	train_h1_max_x_mean_u: 2.61039280891
# 	train_h1_max_x_min_u: 0.0
# 	train_h1_mean_x_max_u: 2.55444598198
# 	train_h1_mean_x_mean_u: 0.837123394012
# 	train_h1_mean_x_min_u: 0.0
# 	train_h1_min_x_max_u: 0.06248851493
# 	train_h1_min_x_mean_u: 0.000725128513295
# 	train_h1_min_x_min_u: 0.0
# 	train_h1_range_x_max_u: 7.88111543655
# 	train_h1_range_x_mean_u: 2.60966730118
# 	train_h1_range_x_min_u: 0.0
# 	train_h1_row_norms_max: 1.24253559113
# 	train_h1_row_norms_mean: 1.04946482182
# 	train_h1_row_norms_min: 0.890857934952
# 	train_objective: 0.382768630981
# 	train_y_col_norms_max: 1.22743856907
# 	train_y_col_norms_mean: 0.978164553642
# 	train_y_col_norms_min: 0.755949676037
# 	train_y_max_max_class: 0.996851742268
# 	train_y_mean_max_class: 0.800312995911
# 	train_y_min_max_class: 0.287817567587
# 	train_y_misclass: 0.10000000149
# 	train_y_nll: 0.382768630981
# 	train_y_row_norms_max: 0.64081287384
# 	train_y_row_norms_mean: 0.254772484303
# 	train_y_row_norms_min: 0.00266337138601
# 	training_seconds_this_epoch: 0.0768520012498
# Time this epoch: 0.076838 seconds
# Monitoring step:
# 	Epochs seen: 9
# 	Batches seen: 90
# 	Examples seen: 9000
# 	learning_rate: 0.099999986589
# 	momentum: 0.500000059605
# 	test_h0_col_norms_max: 1.21042382717
# 	test_h0_col_norms_mean: 1.05139183998
# 	test_h0_col_norms_min: 0.959612369537
# 	test_h0_max_x_max_u: 5.23728370667
# 	test_h0_max_x_mean_u: 1.98849892616
# 	test_h0_max_x_min_u: 0.0686023682356
# 	test_h0_mean_x_max_u: 2.33452033997
# 	test_h0_mean_x_mean_u: 0.673880696297
# 	test_h0_mean_x_min_u: 0.00141649576835
# 	test_h0_min_x_max_u: 0.598745048046
# 	test_h0_min_x_mean_u: 0.0114188473672
# 	test_h0_min_x_min_u: 0.0
# 	test_h0_range_x_max_u: 5.22485589981
# 	test_h0_range_x_mean_u: 1.97707986832
# 	test_h0_range_x_min_u: 0.0686023682356
# 	test_h0_row_norms_max: 0.495743811131
# 	test_h0_row_norms_mean: 0.374224215746
# 	test_h0_row_norms_min: 0.280473798513
# 	test_h1_col_norms_max: 1.29437077045
# 	test_h1_col_norms_mean: 1.05243492126
# 	test_h1_col_norms_min: 0.870068728924
# 	test_h1_max_x_max_u: 8.14818382263
# 	test_h1_max_x_mean_u: 2.75054955482
# 	test_h1_max_x_min_u: 0.0
# 	test_h1_mean_x_max_u: 2.54476070404
# 	test_h1_mean_x_mean_u: 0.879209578037
# 	test_h1_mean_x_min_u: 0.0
# 	test_h1_min_x_max_u: 0.0774512737989
# 	test_h1_min_x_mean_u: 0.00121434987523
# 	test_h1_min_x_min_u: 0.0
# 	test_h1_range_x_max_u: 8.14818382263
# 	test_h1_range_x_mean_u: 2.749335289
# 	test_h1_range_x_min_u: 0.0
# 	test_h1_row_norms_max: 1.24782478809
# 	test_h1_row_norms_mean: 1.05328190327
# 	test_h1_row_norms_min: 0.891310214996
# 	test_objective: 0.562562406063
# 	test_y_col_norms_max: 1.26394033432
# 	test_y_col_norms_mean: 1.02366733551
# 	test_y_col_norms_min: 0.801639020443
# 	test_y_max_max_class: 0.996918797493
# 	test_y_mean_max_class: 0.782383561134
# 	test_y_min_max_class: 0.272926717997
# 	test_y_misclass: 0.159999996424
# 	test_y_nll: 0.562562406063
# 	test_y_row_norms_max: 0.66804343462
# 	test_y_row_norms_mean: 0.266814947128
# 	test_y_row_norms_min: 0.00266337138601
# 	total_seconds_last_epoch: 0.391522973776
# 	train_h0_col_norms_max: 1.21042382717
# 	train_h0_col_norms_mean: 1.05139183998
# 	train_h0_col_norms_min: 0.959612369537
# 	train_h0_max_x_max_u: 5.04359769821
# 	train_h0_max_x_mean_u: 1.94545042515
# 	train_h0_max_x_min_u: 0.0644600838423
# 	train_h0_mean_x_max_u: 2.27801418304
# 	train_h0_mean_x_mean_u: 0.656861424446
# 	train_h0_mean_x_min_u: 0.0010711546056
# 	train_h0_min_x_max_u: 0.619264960289
# 	train_h0_min_x_mean_u: 0.00865776557475
# 	train_h0_min_x_min_u: 0.0
# 	train_h0_range_x_max_u: 5.03672027588
# 	train_h0_range_x_mean_u: 1.93679261208
# 	train_h0_range_x_min_u: 0.0644600838423
# 	train_h0_row_norms_max: 0.495743811131
# 	train_h0_row_norms_mean: 0.374224215746
# 	train_h0_row_norms_min: 0.280473798513
# 	train_h1_col_norms_max: 1.29437077045
# 	train_h1_col_norms_mean: 1.05243492126
# 	train_h1_col_norms_min: 0.870068728924
# 	train_h1_max_x_max_u: 7.94437932968
# 	train_h1_max_x_mean_u: 2.69649624825
# 	train_h1_max_x_min_u: 0.0
# 	train_h1_mean_x_max_u: 2.53754758835
# 	train_h1_mean_x_mean_u: 0.861332058907
# 	train_h1_mean_x_min_u: 0.0
# 	train_h1_min_x_max_u: 0.0527574419975
# 	train_h1_min_x_mean_u: 0.000555102771614
# 	train_h1_min_x_min_u: 0.0
# 	train_h1_range_x_max_u: 7.94437932968
# 	train_h1_range_x_mean_u: 2.69594097137
# 	train_h1_range_x_min_u: 0.0
# 	train_h1_row_norms_max: 1.24782478809
# 	train_h1_row_norms_mean: 1.05328190327
# 	train_h1_row_norms_min: 0.891310214996
# 	train_objective: 0.351353615522
# 	train_y_col_norms_max: 1.26394033432
# 	train_y_col_norms_mean: 1.02366733551
# 	train_y_col_norms_min: 0.801639020443
# 	train_y_max_max_class: 0.998119235039
# 	train_y_mean_max_class: 0.819598913193
# 	train_y_min_max_class: 0.311893731356
# 	train_y_misclass: 0.0949999913573
# 	train_y_nll: 0.351353615522
# 	train_y_row_norms_max: 0.66804343462
# 	train_y_row_norms_mean: 0.266814947128
# 	train_y_row_norms_min: 0.00266337138601
# 	training_seconds_this_epoch: 0.0768379941583
# Time this epoch: 0.076683 seconds
# Monitoring step:
# 	Epochs seen: 10
# 	Batches seen: 100
# 	Examples seen: 10000
# 	learning_rate: 0.099999986589
# 	momentum: 0.500000059605
# 	test_h0_col_norms_max: 1.23557794094
# 	test_h0_col_norms_mean: 1.05545055866
# 	test_h0_col_norms_min: 0.962563753128
# 	test_h0_max_x_max_u: 5.10529375076
# 	test_h0_max_x_mean_u: 2.01641106606
# 	test_h0_max_x_min_u: 0.0810308307409
# 	test_h0_mean_x_max_u: 2.22507834435
# 	test_h0_mean_x_mean_u: 0.680157065392
# 	test_h0_mean_x_min_u: 0.00166573619936
# 	test_h0_min_x_max_u: 0.598347783089
# 	test_h0_min_x_mean_u: 0.0095747243613
# 	test_h0_min_x_min_u: 0.0
# 	test_h0_range_x_max_u: 5.09927988052
# 	test_h0_range_x_mean_u: 2.00683641434
# 	test_h0_range_x_min_u: 0.0810308307409
# 	test_h0_row_norms_max: 0.503167450428
# 	test_h0_row_norms_mean: 0.375609278679
# 	test_h0_row_norms_min: 0.280473798513
# 	test_h1_col_norms_max: 1.29984366894
# 	test_h1_col_norms_mean: 1.05600309372
# 	test_h1_col_norms_min: 0.874703466892
# 	test_h1_max_x_max_u: 8.38683700562
# 	test_h1_max_x_mean_u: 2.80211305618
# 	test_h1_max_x_min_u: 0.0
# 	test_h1_mean_x_max_u: 2.66854643822
# 	test_h1_mean_x_mean_u: 0.881503105164
# 	test_h1_mean_x_min_u: 0.0
# 	test_h1_min_x_max_u: 0.0255277194083
# 	test_h1_min_x_mean_u: 0.000376855314244
# 	test_h1_min_x_min_u: 0.0
# 	test_h1_range_x_max_u: 8.38683700562
# 	test_h1_range_x_mean_u: 2.80173611641
# 	test_h1_range_x_min_u: 0.0
# 	test_h1_row_norms_max: 1.25574398041
# 	test_h1_row_norms_mean: 1.0569344759
# 	test_h1_row_norms_min: 0.891548454762
# 	test_objective: 0.502181708813
# 	test_y_col_norms_max: 1.29418241978
# 	test_y_col_norms_mean: 1.06550705433
# 	test_y_col_norms_min: 0.834318339825
# 	test_y_max_max_class: 0.998865067959
# 	test_y_mean_max_class: 0.801096379757
# 	test_y_min_max_class: 0.282263696194
# 	test_y_misclass: 0.156000003219
# 	test_y_nll: 0.502181708813
# 	test_y_row_norms_max: 0.70500010252
# 	test_y_row_norms_mean: 0.277966141701
# 	test_y_row_norms_min: 0.00266337138601
# 	total_seconds_last_epoch: 0.391250967979
# 	train_h0_col_norms_max: 1.23557794094
# 	train_h0_col_norms_mean: 1.05545055866
# 	train_h0_col_norms_min: 0.962563753128
# 	train_h0_max_x_max_u: 4.98928642273
# 	train_h0_max_x_mean_u: 1.97139668465
# 	train_h0_max_x_min_u: 0.0727752968669
# 	train_h0_mean_x_max_u: 2.17031216621
# 	train_h0_mean_x_mean_u: 0.662902116776
# 	train_h0_mean_x_min_u: 0.00133575883228
# 	train_h0_min_x_max_u: 0.613275527954
# 	train_h0_min_x_mean_u: 0.00743194669485
# 	train_h0_min_x_min_u: 0.0
# 	train_h0_range_x_max_u: 4.98928642273
# 	train_h0_range_x_mean_u: 1.96396493912
# 	train_h0_range_x_min_u: 0.0727752968669
# 	train_h0_row_norms_max: 0.503167450428
# 	train_h0_row_norms_mean: 0.375609278679
# 	train_h0_row_norms_min: 0.280473798513
# 	train_h1_col_norms_max: 1.29984366894
# 	train_h1_col_norms_mean: 1.05600309372
# 	train_h1_col_norms_min: 0.874703466892
# 	train_h1_max_x_max_u: 8.23232650757
# 	train_h1_max_x_mean_u: 2.74831795692
# 	train_h1_max_x_min_u: 0.0
# 	train_h1_mean_x_max_u: 2.60985064507
# 	train_h1_mean_x_mean_u: 0.864189982414
# 	train_h1_mean_x_min_u: 0.0
# 	train_h1_min_x_max_u: 0.0363659411669
# 	train_h1_min_x_mean_u: 0.000363659433788
# 	train_h1_min_x_min_u: 0.0
# 	train_h1_range_x_max_u: 8.23232650757
# 	train_h1_range_x_mean_u: 2.74795436859
# 	train_h1_range_x_min_u: 0.0
# 	train_h1_row_norms_max: 1.25574398041
# 	train_h1_row_norms_mean: 1.0569344759
# 	train_h1_row_norms_min: 0.891548454762
# 	train_objective: 0.301149189472
# 	train_y_col_norms_max: 1.29418241978
# 	train_y_col_norms_mean: 1.06550705433
# 	train_y_col_norms_min: 0.834318339825
# 	train_y_max_max_class: 0.998896121979
# 	train_y_mean_max_class: 0.843701899052
# 	train_y_min_max_class: 0.332697063684
# 	train_y_misclass: 0.082999996841
# 	train_y_nll: 0.301149189472
# 	train_y_row_norms_max: 0.70500010252
# 	train_y_row_norms_mean: 0.277966141701
# 	train_y_row_norms_min: 0.00266337138601
# 	training_seconds_this_epoch: 0.0766830071807
# Saving to ./model_mnist.pkl...
# Saving to ./model_mnist.pkl done. Time elapsed: 0.079974 seconds
# Time this epoch: 0.076912 seconds
# Monitoring step:
# 	Epochs seen: 11
# 	Batches seen: 110
# 	Examples seen: 11000
# 	learning_rate: 0.099999986589
# 	momentum: 0.500000059605
# 	test_h0_col_norms_max: 1.25335729122
# 	test_h0_col_norms_mean: 1.05905938148
# 	test_h0_col_norms_min: 0.964543700218
# 	test_h0_max_x_max_u: 5.2987985611
# 	test_h0_max_x_mean_u: 2.04572296143
# 	test_h0_max_x_min_u: 0.0866454318166
# 	test_h0_mean_x_max_u: 2.35758185387
# 	test_h0_mean_x_mean_u: 0.690596044064
# 	test_h0_mean_x_min_u: 0.00182079733349
# 	test_h0_min_x_max_u: 0.590359926224
# 	test_h0_min_x_mean_u: 0.0109091578051
# 	test_h0_min_x_min_u: 0.0
# 	test_h0_range_x_max_u: 5.28407907486
# 	test_h0_range_x_mean_u: 2.0348136425
# 	test_h0_range_x_min_u: 0.0866454318166
# 	test_h0_row_norms_max: 0.511548280716
# 	test_h0_row_norms_mean: 0.37684443593
# 	test_h0_row_norms_min: 0.280473798513
# 	test_h1_col_norms_max: 1.30880248547
# 	test_h1_col_norms_mean: 1.05919194221
# 	test_h1_col_norms_min: 0.879486143589
# 	test_h1_max_x_max_u: 8.47961425781
# 	test_h1_max_x_mean_u: 2.88864159584
# 	test_h1_max_x_min_u: 0.0
# 	test_h1_mean_x_max_u: 2.64655375481
# 	test_h1_mean_x_mean_u: 0.918162703514
# 	test_h1_mean_x_min_u: 0.0
# 	test_h1_min_x_max_u: 0.0780160352588
# 	test_h1_min_x_mean_u: 0.00123767822515
# 	test_h1_min_x_min_u: 0.0
# 	test_h1_range_x_max_u: 8.47961425781
# 	test_h1_range_x_mean_u: 2.887403965
# 	test_h1_range_x_min_u: 0.0
# 	test_h1_row_norms_max: 1.27046346664
# 	test_h1_row_norms_mean: 1.06017994881
# 	test_h1_row_norms_min: 0.89188170433
# 	test_objective: 0.508433103561
# 	test_y_col_norms_max: 1.32279527187
# 	test_y_col_norms_mean: 1.10169160366
# 	test_y_col_norms_min: 0.879823625088
# 	test_y_max_max_class: 0.999233484268
# 	test_y_mean_max_class: 0.820999860764
# 	test_y_min_max_class: 0.310878247023
# 	test_y_misclass: 0.144000008702
# 	test_y_nll: 0.508433103561
# 	test_y_row_norms_max: 0.716839492321
# 	test_y_row_norms_mean: 0.287569135427
# 	test_y_row_norms_min: 0.00266337138601
# 	total_seconds_last_epoch: 0.498600929976
# 	train_h0_col_norms_max: 1.25335729122
# 	train_h0_col_norms_mean: 1.05905938148
# 	train_h0_col_norms_min: 0.964543700218
# 	train_h0_max_x_max_u: 5.14989566803
# 	train_h0_max_x_mean_u: 1.99691367149
# 	train_h0_max_x_min_u: 0.0791974589229
# 	train_h0_mean_x_max_u: 2.29658269882
# 	train_h0_mean_x_mean_u: 0.673060178757
# 	train_h0_mean_x_min_u: 0.00153974723071
# 	train_h0_min_x_max_u: 0.606921255589
# 	train_h0_min_x_mean_u: 0.00873211864382
# 	train_h0_min_x_min_u: 0.0
# 	train_h0_range_x_max_u: 5.1348195076
# 	train_h0_range_x_mean_u: 1.98818135262
# 	train_h0_range_x_min_u: 0.0791974589229
# 	train_h0_row_norms_max: 0.511548280716
# 	train_h0_row_norms_mean: 0.37684443593
# 	train_h0_row_norms_min: 0.280473798513
# 	train_h1_col_norms_max: 1.30880248547
# 	train_h1_col_norms_mean: 1.05919194221
# 	train_h1_col_norms_min: 0.879486143589
# 	train_h1_max_x_max_u: 8.30659675598
# 	train_h1_max_x_mean_u: 2.82923531532
# 	train_h1_max_x_min_u: 0.0
# 	train_h1_mean_x_max_u: 2.64465999603
# 	train_h1_mean_x_mean_u: 0.899735271931
# 	train_h1_mean_x_min_u: 0.0
# 	train_h1_min_x_max_u: 0.0357568822801
# 	train_h1_min_x_mean_u: 0.000409733387642
# ...
# 	train_h1_row_norms_mean: 1.0744549036
# 	train_h1_row_norms_min: 0.893976449966
# 	train_objective: 0.155664160848
# 	train_y_col_norms_max: 1.43042373657
# 	train_y_col_norms_mean: 1.24442100525
# 	train_y_col_norms_min: 1.03444623947
# 	train_y_max_max_class: 0.999903380871
# 	train_y_mean_max_class: 0.905024886131
# 	train_y_min_max_class: 0.349106669426
# 	train_y_misclass: 0.0359999984503
# 	train_y_nll: 0.155664160848
# 	train_y_row_norms_max: 0.807280480862
# 	train_y_row_norms_mean: 0.326072484255
# 	train_y_row_norms_min: 0.00266337138601
# 	training_seconds_this_epoch: 0.0773079991341
# Time this epoch: 0.076765 seconds
# Monitoring step:
# 	Epochs seen: 17
# 	Batches seen: 170
# 	Examples seen: 17000
# 	learning_rate: 0.099999986589
# 	momentum: 0.500000059605
# 	test_h0_col_norms_max: 1.34282577038
# 	test_h0_col_norms_mean: 1.07798469067
# 	test_h0_col_norms_min: 0.970460116863
# 	test_h0_max_x_max_u: 5.36118173599
# 	test_h0_max_x_mean_u: 2.11505937576
# 	test_h0_max_x_min_u: 0.112354725599
# 	test_h0_mean_x_max_u: 2.41735649109
# 	test_h0_mean_x_mean_u: 0.703463435173
# 	test_h0_mean_x_min_u: 0.00249769957736
# 	test_h0_min_x_max_u: 0.551767468452
# 	test_h0_min_x_mean_u: 0.0101659270003
# 	test_h0_min_x_min_u: 0.0
# 	test_h0_range_x_max_u: 5.34299945831
# 	test_h0_range_x_mean_u: 2.10489344597
# 	test_h0_range_x_min_u: 0.112354725599
# 	test_h0_row_norms_max: 0.551928222179
# 	test_h0_row_norms_mean: 0.383294433355
# 	test_h0_row_norms_min: 0.280473798513
# 	test_h1_col_norms_max: 1.3447688818
# 	test_h1_col_norms_mean: 1.07580840588
# 	test_h1_col_norms_min: 0.896570086479
# 	test_h1_max_x_max_u: 8.9066696167
# 	test_h1_max_x_mean_u: 3.11536884308
# 	test_h1_max_x_min_u: 0.0
# 	test_h1_mean_x_max_u: 2.82497262955
# 	test_h1_mean_x_mean_u: 0.970781683922
# 	test_h1_mean_x_min_u: 0.0
# 	test_h1_min_x_max_u: 0.0630861967802
# 	test_h1_min_x_mean_u: 0.000853632576764
# 	test_h1_min_x_min_u: 0.0
# 	test_h1_range_x_max_u: 8.9066696167
# 	test_h1_range_x_mean_u: 3.11451530457
# 	test_h1_range_x_min_u: 0.0
# 	test_h1_row_norms_max: 1.34632813931
# 	test_h1_row_norms_mean: 1.0771780014
# 	test_h1_row_norms_min: 0.89445245266
# 	test_objective: 0.499997317791
# 	test_y_col_norms_max: 1.45787668228
# 	test_y_col_norms_mean: 1.26962137222
# 	test_y_col_norms_min: 1.06204032898
# 	test_y_max_max_class: 0.999864578247
# 	test_y_mean_max_class: 0.87062984705
# 	test_y_min_max_class: 0.332253485918
# 	test_y_misclass: 0.129999995232
# 	test_y_nll: 0.499997317791
# 	test_y_row_norms_max: 0.820121824741
# 	test_y_row_norms_mean: 0.332938224077
# 	test_y_row_norms_min: 0.00266337138601
# 	total_seconds_last_epoch: 0.392895966768
# 	train_h0_col_norms_max: 1.34282577038
# 	train_h0_col_norms_mean: 1.07798469067
# 	train_h0_col_norms_min: 0.970460116863
# 	train_h0_max_x_max_u: 5.11973667145
# 	train_h0_max_x_mean_u: 2.06346940994
# 	train_h0_max_x_min_u: 0.103111185133
# 	train_h0_mean_x_max_u: 2.34504413605
# 	train_h0_mean_x_mean_u: 0.685505449772
# 	train_h0_mean_x_min_u: 0.00216499948874
# 	train_h0_min_x_max_u: 0.580263853073
# 	train_h0_min_x_mean_u: 0.00772378966212
# 	train_h0_min_x_min_u: 0.0
# 	train_h0_range_x_max_u: 5.11168718338
# 	train_h0_range_x_mean_u: 2.05574584007
# 	train_h0_range_x_min_u: 0.103111185133
# 	train_h0_row_norms_max: 0.551928222179
# 	train_h0_row_norms_mean: 0.383294433355
# 	train_h0_row_norms_min: 0.280473798513
# 	train_h1_col_norms_max: 1.3447688818
# 	train_h1_col_norms_mean: 1.07580840588
# 	train_h1_col_norms_min: 0.896570086479
# 	train_h1_max_x_max_u: 8.84166717529
# 	train_h1_max_x_mean_u: 3.05626320839
# 	train_h1_max_x_min_u: 0.0
# 	train_h1_mean_x_max_u: 2.78574609756
# 	train_h1_mean_x_mean_u: 0.951011180878
# 	train_h1_mean_x_min_u: 0.0
# 	train_h1_min_x_max_u: 0.0
# 	train_h1_min_x_mean_u: 0.0
# 	train_h1_min_x_min_u: 0.0
# 	train_h1_range_x_max_u: 8.84166717529
# 	train_h1_range_x_mean_u: 3.05626320839
# 	train_h1_range_x_min_u: 0.0
# 	train_h1_row_norms_max: 1.34632813931
# 	train_h1_row_norms_mean: 1.0771780014
# 	train_h1_row_norms_min: 0.89445245266
# 	train_objective: 0.147527873516
# 	train_y_col_norms_max: 1.45787668228
# 	train_y_col_norms_mean: 1.26962137222
# 	train_y_col_norms_min: 1.06204032898
# 	train_y_max_max_class: 0.999917984009
# 	train_y_mean_max_class: 0.908993124962
# 	train_y_min_max_class: 0.362698823214
# 	train_y_misclass: 0.0330000035465
# 	train_y_nll: 0.147527873516
# 	train_y_row_norms_max: 0.820121824741
# 	train_y_row_norms_mean: 0.332938224077
# 	train_y_row_norms_min: 0.00266337138601
# 	training_seconds_this_epoch: 0.0767650008202
# Time this epoch: 0.076701 seconds
# Monitoring step:
# 	Epochs seen: 18
# 	Batches seen: 180
# 	Examples seen: 18000
# 	learning_rate: 0.099999986589
# 	momentum: 0.500000059605
# 	test_h0_col_norms_max: 1.36036837101
# 	test_h0_col_norms_mean: 1.08088362217
# 	test_h0_col_norms_min: 0.971190273762
# 	test_h0_max_x_max_u: 5.37962865829
# 	test_h0_max_x_mean_u: 2.12070894241
# 	test_h0_max_x_min_u: 0.119706019759
# 	test_h0_mean_x_max_u: 2.42943692207
# 	test_h0_mean_x_mean_u: 0.701944708824
# 	test_h0_mean_x_min_u: 0.00280549121089
# 	test_h0_min_x_max_u: 0.554049432278
# 	test_h0_min_x_mean_u: 0.0102141033858
# 	test_h0_min_x_min_u: 0.0
# 	test_h0_range_x_max_u: 5.36142396927
# 	test_h0_range_x_mean_u: 2.11049461365
# 	test_h0_range_x_min_u: 0.119706019759
# 	test_h0_row_norms_max: 0.557518601418
# 	test_h0_row_norms_mean: 0.384280800819
# 	test_h0_row_norms_min: 0.280473798513
# 	test_h1_col_norms_max: 1.3490973711
# 	test_h1_col_norms_mean: 1.07836294174
# 	test_h1_col_norms_min: 0.896570086479
# 	test_h1_max_x_max_u: 9.4879989624
# 	test_h1_max_x_mean_u: 3.14028596878
# 	test_h1_max_x_min_u: 0.0
# 	test_h1_mean_x_max_u: 3.05321621895
# 	test_h1_mean_x_mean_u: 0.976984739304
# 	test_h1_mean_x_min_u: 0.0
# 	test_h1_min_x_max_u: 0.0363551490009
# 	test_h1_min_x_mean_u: 0.00043936088332
# 	test_h1_min_x_min_u: 0.0
# 	test_h1_range_x_max_u: 9.4879989624
# 	test_h1_range_x_mean_u: 3.1398460865
# 	test_h1_range_x_min_u: 0.0
# 	test_h1_row_norms_max: 1.36258947849
# 	test_h1_row_norms_mean: 1.07979047298
# 	test_h1_row_norms_min: 0.8949213624
# 	test_objective: 0.493919700384
# 	test_y_col_norms_max: 1.47577524185
# 	test_y_col_norms_mean: 1.29343950748
# 	test_y_col_norms_min: 1.08780992031
# 	test_y_max_max_class: 0.99991106987
# 	test_y_mean_max_class: 0.870437264442
# 	test_y_min_max_class: 0.340471714735
# 	test_y_misclass: 0.148000001907
# 	test_y_nll: 0.493919700384
# 	test_y_row_norms_max: 0.838829219341
# 	test_y_row_norms_mean: 0.339229732752
# 	test_y_row_norms_min: 0.00266337138601
# 	total_seconds_last_epoch: 0.392343997955
# 	train_h0_col_norms_max: 1.36036837101
# 	train_h0_col_norms_mean: 1.08088362217
# 	train_h0_col_norms_min: 0.971190273762
# 	train_h0_max_x_max_u: 5.19341230392
# 	train_h0_max_x_mean_u: 2.06951165199
# 	train_h0_max_x_min_u: 0.111943788826
# 	train_h0_mean_x_max_u: 2.35668778419
# 	train_h0_mean_x_mean_u: 0.68404597044
# 	train_h0_mean_x_min_u: 0.00236209016293
# 	train_h0_min_x_max_u: 0.585445165634
# 	train_h0_min_x_mean_u: 0.00744519708678
# 	train_h0_min_x_min_u: 0.0
# 	train_h0_range_x_max_u: 5.16996622086
# 	train_h0_range_x_mean_u: 2.0620663166
# 	train_h0_range_x_min_u: 0.111943788826
# 	train_h0_row_norms_max: 0.557518601418
# 	train_h0_row_norms_mean: 0.384280800819
# 	train_h0_row_norms_min: 0.280473798513
# 	train_h1_col_norms_max: 1.3490973711
# 	train_h1_col_norms_mean: 1.07836294174
# 	train_h1_col_norms_min: 0.896570086479
# 	train_h1_max_x_max_u: 9.24939441681
# 	train_h1_max_x_mean_u: 3.07910609245
# 	train_h1_max_x_min_u: 0.0
# 	train_h1_mean_x_max_u: 2.98392343521
# 	train_h1_mean_x_mean_u: 0.956997871399
# 	train_h1_mean_x_min_u: 0.0
# 	train_h1_min_x_max_u: 0.0178324989974
# 	train_h1_min_x_mean_u: 0.000178324989974
# 	train_h1_min_x_min_u: 0.0
# 	train_h1_range_x_max_u: 9.24939441681
# 	train_h1_range_x_mean_u: 3.07892799377
# 	train_h1_range_x_min_u: 0.0
# 	train_h1_row_norms_max: 1.36258947849
# 	train_h1_row_norms_mean: 1.07979047298
# 	train_h1_row_norms_min: 0.8949213624
# 	train_objective: 0.140654325485
# 	train_y_col_norms_max: 1.47577524185
# 	train_y_col_norms_mean: 1.29343950748
# 	train_y_col_norms_min: 1.08780992031
# 	train_y_max_max_class: 0.999949634075
# 	train_y_mean_max_class: 0.912002623081
# 	train_y_min_max_class: 0.359933674335
# 	train_y_misclass: 0.0299999993294
# 	train_y_nll: 0.140654325485
# 	train_y_row_norms_max: 0.838829219341
# 	train_y_row_norms_mean: 0.339229732752
# 	train_y_row_norms_min: 0.00266337138601
# 	training_seconds_this_epoch: 0.0767010003328
# Time this epoch: 0.076711 seconds
# Monitoring step:
# 	Epochs seen: 19
# 	Batches seen: 190
# 	Examples seen: 19000
# 	learning_rate: 0.099999986589
# 	momentum: 0.500000059605
# 	test_h0_col_norms_max: 1.37143599987
# 	test_h0_col_norms_mean: 1.08365881443
# 	test_h0_col_norms_min: 0.971715211868
# 	test_h0_max_x_max_u: 5.36840486526
# 	test_h0_max_x_mean_u: 2.12656331062
# 	test_h0_max_x_min_u: 0.123854331672
# 	test_h0_mean_x_max_u: 2.40991473198
# 	test_h0_mean_x_mean_u: 0.702306210995
# 	test_h0_mean_x_min_u: 0.00299808918498
# 	test_h0_min_x_max_u: 0.534740746021
# 	test_h0_min_x_mean_u: 0.00993497017771
# 	test_h0_min_x_min_u: 0.0
# 	test_h0_range_x_max_u: 5.35095453262
# 	test_h0_range_x_mean_u: 2.11662817001
# 	test_h0_range_x_min_u: 0.123854331672
# 	test_h0_row_norms_max: 0.564710319042
# 	test_h0_row_norms_mean: 0.385214805603
# 	test_h0_row_norms_min: 0.280473798513
# 	test_h1_col_norms_max: 1.36141693592
# 	test_h1_col_norms_mean: 1.0807813406
# 	test_h1_col_norms_min: 0.896570086479
# 	test_h1_max_x_max_u: 9.21926689148
# 	test_h1_max_x_mean_u: 3.15925455093
# 	test_h1_max_x_min_u: 0.0
# 	test_h1_mean_x_max_u: 2.91600131989
# 	test_h1_mean_x_mean_u: 0.975942790508
# 	test_h1_mean_x_min_u: 0.0
# 	test_h1_min_x_max_u: 0.04676309973
# 	test_h1_min_x_mean_u: 0.00052209867863
# 	test_h1_min_x_min_u: 0.0
# 	test_h1_range_x_max_u: 9.21926689148
# 	test_h1_range_x_mean_u: 3.15873241425
# 	test_h1_range_x_min_u: 0.0
# 	test_h1_row_norms_max: 1.37135279179
# 	test_h1_row_norms_mean: 1.08229625225
# 	test_h1_row_norms_min: 0.895482897758
# 	test_objective: 0.460972487926
# 	test_y_col_norms_max: 1.49516808987
# 	test_y_col_norms_mean: 1.31553649902
# 	test_y_col_norms_min: 1.11032485962
# 	test_y_max_max_class: 0.999933898449
# 	test_y_mean_max_class: 0.881941497326
# 	test_y_min_max_class: 0.352427333593
# 	test_y_misclass: 0.123000003397
# 	test_y_nll: 0.460972487926
# 	test_y_row_norms_max: 0.848902404308
# 	test_y_row_norms_mean: 0.34513476491
# 	test_y_row_norms_min: 0.00266337138601
# 	total_seconds_last_epoch: 0.3914090693
# 	train_h0_col_norms_max: 1.37143599987
# 	train_h0_col_norms_mean: 1.08365881443
# 	train_h0_col_norms_min: 0.971715211868
# 	train_h0_max_x_max_u: 5.1641201973
# 	train_h0_max_x_mean_u: 2.07583594322
# 	train_h0_max_x_min_u: 0.116156749427
# 	train_h0_mean_x_max_u: 2.33537507057
# 	train_h0_mean_x_mean_u: 0.684384226799
# 	train_h0_mean_x_min_u: 0.00248867250048
# 	train_h0_min_x_max_u: 0.56894415617
# 	train_h0_min_x_mean_u: 0.00741918431595
# 	train_h0_min_x_min_u: 0.0
# 	train_h0_range_x_max_u: 5.15645742416
# 	train_h0_range_x_mean_u: 2.06841659546
# 	train_h0_range_x_min_u: 0.116156749427
# 	train_h0_row_norms_max: 0.564710319042
# 	train_h0_row_norms_mean: 0.385214805603
# 	train_h0_row_norms_min: 0.280473798513
# 	train_h1_col_norms_max: 1.36141693592
# 	train_h1_col_norms_mean: 1.0807813406
# 	train_h1_col_norms_min: 0.896570086479
# 	train_h1_max_x_max_u: 9.14778137207
# 	train_h1_max_x_mean_u: 3.10251712799
# 	train_h1_max_x_min_u: 0.0
# 	train_h1_mean_x_max_u: 2.88491630554
# 	train_h1_mean_x_mean_u: 0.956087648869
# 	train_h1_mean_x_min_u: 0.0
# 	train_h1_min_x_max_u: 0.00415239948779
# 	train_h1_min_x_mean_u: 4.15239956055e-05
# 	train_h1_min_x_min_u: 0.0
# 	train_h1_range_x_max_u: 9.14778137207
# 	train_h1_range_x_mean_u: 3.10247564316
# 	train_h1_range_x_min_u: 0.0
# 	train_h1_row_norms_max: 1.37135279179
# 	train_h1_row_norms_mean: 1.08229625225
# 	train_h1_row_norms_min: 0.895482897758
# 	train_objective: 0.11272007972
# 	train_y_col_norms_max: 1.49516808987
# 	train_y_col_norms_mean: 1.31553649902
# 	train_y_col_norms_min: 1.11032485962
# 	train_y_max_max_class: 0.99991953373
# 	train_y_mean_max_class: 0.922433435917
# 	train_y_min_max_class: 0.395698159933
# 	train_y_misclass: 0.0210000015795
# 	train_y_nll: 0.11272007972
# 	train_y_row_norms_max: 0.848902404308
# 	train_y_row_norms_mean: 0.34513476491
# 	train_y_row_norms_min: 0.00266337138601
# 	training_seconds_this_epoch: 0.076710999012
# Time this epoch: 0.077043 seconds
# Monitoring step:
# 	Epochs seen: 20
# 	Batches seen: 200
# 	Examples seen: 20000
# 	learning_rate: 0.099999986589
# 	momentum: 0.500000059605
# 	test_h0_col_norms_max: 1.38282668591
# 	test_h0_col_norms_mean: 1.08640444279
# 	test_h0_col_norms_min: 0.971933662891
# 	test_h0_max_x_max_u: 5.3245806694
# 	test_h0_max_x_mean_u: 2.14106059074
# 	test_h0_max_x_min_u: 0.127138972282
# 	test_h0_mean_x_max_u: 2.38005948067
# 	test_h0_mean_x_mean_u: 0.708713293076
# 	test_h0_mean_x_min_u: 0.00312190386467
# 	test_h0_min_x_max_u: 0.554714679718
# 	test_h0_min_x_mean_u: 0.00989470258355
# 	test_h0_min_x_min_u: 0.0
# 	test_h0_range_x_max_u: 5.30910110474
# 	test_h0_range_x_mean_u: 2.13116574287
# 	test_h0_range_x_min_u: 0.127138972282
# 	test_h0_row_norms_max: 0.56689542532
# 	test_h0_row_norms_mean: 0.386148780584
# 	test_h0_row_norms_min: 0.280473798513
# 	test_h1_col_norms_max: 1.36655056477
# 	test_h1_col_norms_mean: 1.08320844173
# 	test_h1_col_norms_min: 0.896570086479
# 	test_h1_max_x_max_u: 9.48558425903
# 	test_h1_max_x_mean_u: 3.20883893967
# 	test_h1_max_x_min_u: 0.0
# 	test_h1_mean_x_max_u: 3.01143312454
# 	test_h1_mean_x_mean_u: 0.997267007828
# 	test_h1_mean_x_min_u: 0.0
# 	test_h1_min_x_max_u: 0.0436610169709
# 	test_h1_min_x_mean_u: 0.000580249004997
# 	test_h1_min_x_min_u: 0.0
# 	test_h1_range_x_max_u: 9.48558425903
# 	test_h1_range_x_mean_u: 3.20825862885
# 	test_h1_range_x_min_u: 0.0
# 	test_h1_row_norms_max: 1.38067495823
# 	test_h1_row_norms_mean: 1.08479678631
# 	test_h1_row_norms_min: 0.895965099335
# 	test_objective: 0.472773820162
# 	test_y_col_norms_max: 1.52235996723
# 	test_y_col_norms_mean: 1.33737313747
# 	test_y_col_norms_min: 1.1340098381
# 	test_y_max_max_class: 0.999922096729
# 	test_y_mean_max_class: 0.884098291397
# 	test_y_min_max_class: 0.361968785524
# 	test_y_misclass: 0.126000002027
# 	test_y_nll: 0.472773820162
# 	test_y_row_norms_max: 0.863828599453
# 	test_y_row_norms_mean: 0.350933045149
# 	test_y_row_norms_min: 0.00266337138601
# 	total_seconds_last_epoch: 0.393661975861
# 	train_h0_col_norms_max: 1.38282668591
# 	train_h0_col_norms_mean: 1.08640444279
# 	train_h0_col_norms_min: 0.971933662891
# 	train_h0_max_x_max_u: 5.14531040192
# 	train_h0_max_x_mean_u: 2.08976364136
# 	train_h0_max_x_min_u: 0.121576607227
# 	train_h0_mean_x_max_u: 2.3057539463
# 	train_h0_mean_x_mean_u: 0.690565824509
# 	train_h0_mean_x_min_u: 0.00260553648695
# 	train_h0_min_x_max_u: 0.593227982521
# 	train_h0_min_x_mean_u: 0.00747096119449
# 	train_h0_min_x_min_u: 0.0
# 	train_h0_range_x_max_u: 5.14017391205
# 	train_h0_range_x_mean_u: 2.08229255676
# 	train_h0_range_x_min_u: 0.121576607227
# 	train_h0_row_norms_max: 0.56689542532
# 	train_h0_row_norms_mean: 0.386148780584
# 	train_h0_row_norms_min: 0.280473798513
# 	train_h1_col_norms_max: 1.36655056477
# 	train_h1_col_norms_mean: 1.08320844173
# 	train_h1_col_norms_min: 0.896570086479
# 	train_h1_max_x_max_u: 9.36334991455
# 	train_h1_max_x_mean_u: 3.14843082428
# 	train_h1_max_x_min_u: 0.0
# 	train_h1_mean_x_max_u: 2.98397874832
# 	train_h1_mean_x_mean_u: 0.977112054825
# 	train_h1_mean_x_min_u: 0.0
# 	train_h1_min_x_max_u: 0.00650532450527
# 	train_h1_min_x_mean_u: 6.50532456348e-05
# 	train_h1_min_x_min_u: 0.0
# 	train_h1_range_x_max_u: 9.36334991455
# 	train_h1_range_x_mean_u: 3.14836573601
# 	train_h1_range_x_min_u: 0.0
# 	train_h1_row_norms_max: 1.38067495823
# 	train_h1_row_norms_mean: 1.08479678631
# 	train_h1_row_norms_min: 0.895965099335
# 	train_objective: 0.098839096725
# 	train_y_col_norms_max: 1.52235996723
# 	train_y_col_norms_mean: 1.33737313747
# 	train_y_col_norms_min: 1.1340098381
# 	train_y_max_max_class: 0.999954998493
# 	train_y_mean_max_class: 0.927945494652
# 	train_y_min_max_class: 0.41922056675
# 	train_y_misclass: 0.01600000076
# 	train_y_nll: 0.098839096725
# 	train_y_row_norms_max: 0.863828599453
# 	train_y_row_norms_mean: 0.350933045149
# 	train_y_row_norms_min: 0.00266337138601
# 	training_seconds_this_epoch: 0.0770429968834
# Saving to ./model_mnist.pkl...
# Saving to ./model_mnist.pkl done. Time elapsed: 0.099798 seconds
# Saving to ./model_mnist.pkl...
# Saving to ./model_mnist.pkl done. Time elapsed: 0.095648 seconds

# %%
# Load saved model.
model = pickle.load(open(filename_model, 'r'))

# Print objective function after training.
channels = model.monitor.channels
print 'Train objective = %f' % channels['train_y_misclass'].val_record[-1]
print 'Valid objective = %f' % channels['test_y_misclass'].val_record[-1]
# Out:
# Train objective = 0.016000
# Valid objective = 0.126000
